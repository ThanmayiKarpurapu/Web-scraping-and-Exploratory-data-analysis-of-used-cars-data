# %%
#IMPORTING LIBRARIES
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import re
import time

# %%
#WEBSCRAPING CODE
Title=[]
Price=[]
Brand=[]
Fuel_type=[]
Kilometers=[]
City=[]
Year=[]
Model=[]
#https://www.cartrade.com/buy-used-cars/bangalore/c/#city=2&sc=-1&so=-1&pn=1
for i in range(1,20):
    url= f'https://www.cartrade.com/buy-used-cars/bangalore/c/#city=2&sc=-1&so=-1&pn={i}'
    response=requests.get(url)
    soup=BeautifulSoup(response.text)
    
    container=soup.find_all("div",class_="details_out")
    for i in container:
        title=i.find("h2",class_="h2heading truncate")
        
        regex=re.findall("\d+\s((?:Toyota|Tata|Datsun|Maruti Suzuki|Mercedes-Benz|BMW|Ford|Honda|Audi|Hyundai|Nissan|Skoda|Mahindra|Jaguar|Kia|Land Rover|MG|MINI Cooper|Land Rover|Volkswagen|Bentley|Volvo|Jeep|Volks Wagon|Renault))",title.text)
        if regex:
            Brand.append(regex[0])
        else:
            Brand.append(np.nan)
                
    for i in container:
        model = i.find("h2",class_= "h2heading truncate")
        regex= re.findall("\d+\s(?:Toyota|Tata|Datsun|Maruti Suzuki|Mercedes-Benz|BMW|Ford|Honda|Audi|Hyundai|Nissan|Skoda|Mahindra|Jaguar|Kia|Land Rover|MG|MINI Cooper|Land Rover|Volkswagen|Jeep|Volks Wagon|Bentley|Volvo|Renault)(.*)\s",model.text)
        if regex:
            Model.append(regex[0])
        else:
            Model.append(np.nan)
    for i in container:
        price=i.find("div",class_="cr_prc")
        text=price.text
        #print(text)
        regex=re.findall("₹(\d+,?\d+,?\d+)",text)
        if regex:
            Price.append(regex[0])
        else:
            Price.append(np.nan)
            
    for i in container:
        kilometers= i.find("div",class_="info_cr_new")
        text1=kilometers.text
        #print(text1)
        regex=re.findall("(\d+?,\d+)\sKMs",text1)
        if regex:
            Kilometers.append(regex[0])
        else:
            Kilometers.append(np.nan)
            
            
    for i in container:
        fuel_type= i.find("div",class_="info_cr_new")
        text2=fuel_type.text
        regex=re.findall("KMs\W(\w+)",text2)
        if regex:
            Fuel_type.append(regex[0])
        else:
            Fuel_type.append(np.nan)
            
    for i in container:
        city=i.find("div",class_="info_cr_new")
        text3=city.text
        regex=re.findall("(\w+)$",text3)
        if regex:
            City.append(regex[0])
        else:
            City.append(np.nan)
            
    for i in container:
        year= i.find("h2",class_="h2heading truncate")
        print(year.text)
        regex=re.findall("\W+(\d+).*",year.text)
        if regex:
            Year.append(regex[0])
        else:
            Year.append(np.nan)
                
        #\d+\s(?:Toyota|Tata|Datsun|Maruti Suzuki|Mercedes-Benz|BMW|Ford|Honda|Audi|Hyundai|Nissan|Skoda|Mahindra|Jaguar|Kia|Land Rover|MG|MINI Cooper|Land Rover|Volkswagen|Jeep|Volks Wagon|Renault)(.*)\s(?:Petrol|Diesel)
# Out:
# 												2022 Audi Q5 Technology 45 TFSI
#
#
# 												2011 Audi A4 1.8 TFSI
#
#
# 												2013 BMW X1 sDrive20d
#
#
# 												2021 Toyota Innova Crysta ZX 2.4 AT 7 STR
#
#
# 												2018 Hyundai Creta E Plus 1.6 Petrol
#
#
# 												2019 Kia Seltos GTX AT 1.4
#
#
# 												2020 Toyota Innova Crysta 2.4 ZX AT 7 STR
#
#
# 												2021 Toyota Innova Crysta ZX 2.4 AT 7 STR
#
#
# 												2018 Maruti Suzuki Baleno Zeta
#
#
# 												2018 Hyundai Creta SX Plus 1.6  Petrol
#
#
# 												2020 Honda City ZX Petrol [2019-2019]
#
#
# 												2020 Maruti Suzuki XL6 Zeta AT Petrol
#
#
# 												2021 Hyundai i20 Asta 1.0 Turbo DCT
#
#
# 												2013 Hyundai i20 Sportz (AT) 1.4
#
#
# 												2019 Land Rover Range Rover Sport SE 3.0 Diesel [2018-2020]
#
#
# 												2019 Hyundai Creta SX 1.6 AT Petrol
#
#
# 												2017 Volkswagen Vento Highline 1.2 (P) AT
#
#
# 												2018 Maruti Suzuki Dzire VXi AMT
#
#
# ...

# %%
print(len(Kilometers))
print(len(Brand))
print(len(Price))
print(len(City))
print(len(Fuel_type))
print(len(Year))
print(len(Model))
# Out:
# 608
# 608
# 608
# 608
# 608
# 608
# 608

# %%
BNG = {"Brand" : Brand,"Model":Model,"City":City,"Fuel_type":Fuel_type,"Kilometers_Driven":Kilometers,"Year":Year,"Price":Price}

# %%
DF_BNG = pd.DataFrame(BNG)

# %%
DF_BNG
# Out:
#              Brand                           Model       City Fuel_type  \
# 0             Audi           Q5 Technology 45 TFSI  Bangalore    Petrol
# 1             Audi                     A4 1.8 TFSI  Bangalore    Petrol
# 2              BMW                    X1 sDrive20d  Bangalore    Diesel
# 3           Toyota   Innova Crysta ZX 2.4 AT 7 STR  Bangalore    Diesel
# 4          Hyundai         Creta E Plus 1.6 Petrol  Bangalore    Petrol
# ..             ...                             ...        ...       ...
# 603  Maruti Suzuki                 Swift DZire ZXI  Bangalore    Petrol
# 604  Maruti Suzuki             Wagon R ZXi 1.2 AMT  Bangalore    Petrol
# 605  Mercedes-Benz             C-Class C220d Prime  Bangalore    Diesel
# 606  Maruti Suzuki                 S-Cross Zeta AT  Bangalore    Petrol
# 607          Honda                          City V  Bangalore    Petrol
#
#     Kilometers_Driven  Year      Price
# 0               9,830  2022  60,00,000
# ...

# %%
DF_BNG.isna()
# Out:
#      Brand  Model   City  Fuel_type  Kilometers_Driven   Year  Price
# 0    False  False  False      False              False  False  False
# 1    False  False  False      False              False  False  False
# 2    False  False  False      False              False  False  False
# 3    False  False  False      False              False  False  False
# 4    False  False  False      False              False  False  False
# ..     ...    ...    ...        ...                ...    ...    ...
# 603  False  False  False      False              False  False  False
# 604  False  False  False      False              False  False  False
# 605  False  False  False      False              False  False  False
# 606  False  False  False      False              False  False  False
# 607  False  False  False      False              False  False  False
#
# [608 rows x 7 columns]

# %%
DF_BNG['Kilometers_Driven'] = DF_BNG['Kilometers_Driven'].str.replace(',','')

# %%
DF_BNG['Price'] = DF_BNG['Price'].str.replace(',','')

# %%
DF_BNG['Price'] = DF_BNG['Price'].astype('int64')

# %%
DF_BNG[DF_BNG['Kilometers_Driven'].isna()]
# Out:
# Empty DataFrame
# Columns: [Brand, Model, City, Fuel_type, Kilometers_Driven, Year, Price]
# Index: []

# %%
DF_BNG = DF_BNG.dropna()

# %%
DF_BNG
# Out:
#              Brand                           Model       City Fuel_type  \
# 0             Audi           Q5 Technology 45 TFSI  Bangalore    Petrol
# 1             Audi                     A4 1.8 TFSI  Bangalore    Petrol
# 2              BMW                    X1 sDrive20d  Bangalore    Diesel
# 3           Toyota   Innova Crysta ZX 2.4 AT 7 STR  Bangalore    Diesel
# 4          Hyundai         Creta E Plus 1.6 Petrol  Bangalore    Petrol
# ..             ...                             ...        ...       ...
# 603  Maruti Suzuki                 Swift DZire ZXI  Bangalore    Petrol
# 604  Maruti Suzuki             Wagon R ZXi 1.2 AMT  Bangalore    Petrol
# 605  Mercedes-Benz             C-Class C220d Prime  Bangalore    Diesel
# 606  Maruti Suzuki                 S-Cross Zeta AT  Bangalore    Petrol
# 607          Honda                          City V  Bangalore    Petrol
#
#     Kilometers_Driven  Year    Price
# 0                9830  2022  6000000
# ...

# %%
DF_BNG['Kilometers_Driven'] = DF_BNG['Kilometers_Driven'].astype('int64')

# %%
DF_BNG['Year'] = DF_BNG['Year'].astype('int64')

# %%
DF_BNG.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 608 entries, 0 to 607
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Brand              608 non-null    object
#  1   Model              608 non-null    object
#  2   City               608 non-null    object
#  3   Fuel_type          608 non-null    object
#  4   Kilometers_Driven  608 non-null    int64
#  5   Year               608 non-null    int64
#  6   Price              608 non-null    int64
# dtypes: int64(3), object(4)
# memory usage: 38.0+ KB

# %%
DF_BNG.to_csv("BNG_DATA")

# %%
BNG_DATA_df = pd.read_csv("BNG_DATA")

# %%
BNG_DATA_df
# Out:
#      Unnamed: 0          Brand                           Model       City  \
# 0             0           Audi           Q5 Technology 45 TFSI  Bangalore
# 1             1           Audi                     A4 1.8 TFSI  Bangalore
# 2             2            BMW                    X1 sDrive20d  Bangalore
# 3             3         Toyota   Innova Crysta ZX 2.4 AT 7 STR  Bangalore
# 4             4        Hyundai         Creta E Plus 1.6 Petrol  Bangalore
# ..          ...            ...                             ...        ...
# 603         603  Maruti Suzuki                 Swift DZire ZXI  Bangalore
# 604         604  Maruti Suzuki             Wagon R ZXi 1.2 AMT  Bangalore
# 605         605  Mercedes-Benz             C-Class C220d Prime  Bangalore
# 606         606  Maruti Suzuki                 S-Cross Zeta AT  Bangalore
# 607         607          Honda                          City V  Bangalore
#
#     Fuel_type  Kilometers_Driven  Year    Price
# ...

# %%
BNG_DATA_df.drop('Unnamed: 0',axis=1,inplace= True)

# %%
BNG_DATA_df
# Out:
#              Brand                           Model       City Fuel_type  \
# 0             Audi           Q5 Technology 45 TFSI  Bangalore    Petrol
# 1             Audi                     A4 1.8 TFSI  Bangalore    Petrol
# 2              BMW                    X1 sDrive20d  Bangalore    Diesel
# 3           Toyota   Innova Crysta ZX 2.4 AT 7 STR  Bangalore    Diesel
# 4          Hyundai         Creta E Plus 1.6 Petrol  Bangalore    Petrol
# ..             ...                             ...        ...       ...
# 603  Maruti Suzuki                 Swift DZire ZXI  Bangalore    Petrol
# 604  Maruti Suzuki             Wagon R ZXi 1.2 AMT  Bangalore    Petrol
# 605  Mercedes-Benz             C-Class C220d Prime  Bangalore    Diesel
# 606  Maruti Suzuki                 S-Cross Zeta AT  Bangalore    Petrol
# 607          Honda                          City V  Bangalore    Petrol
#
#      Kilometers_Driven  Year    Price
# 0                 9830  2022  6000000
# ...
